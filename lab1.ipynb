# %% [markdown]
# # Lab 1

# %% [markdown]
# This is my first lab.

# %%
import pandas as pd 

covid_data = pd.read_csv('s3://ia340lab1-bucket-porter/data.csv')

covid_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
housing_data = pd.read_csv('s3://ia340lab1-bucket-porter/Real_Estate_Sales_2001-2023_GL.csv')

housing_data.head()
# Out:
# /tmp/ipykernel_16781/1016700943.py:1: DtypeWarning: Columns (7,8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   housing_data = pd.read_csv('s3://ia340lab1-bucket-porter/Real_Estate_Sales_2001-2023_GL.csv')
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    04/14/2021  Ansonia    323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia   152 JACKSON ST
# 2        2020348       2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    12/14/2020  Ansonia      57 PLATT ST
# 4         210288       2021    06/20/2022     Avon   12 BYRON DRIVE
#
#    Assessed Value  Sale Amount Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0      0.5354   Residential    Single Family
# 1        110500.0     239900.0      0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.463    Commercial              NaN
# ...
